# %%
import numpy as np

# %%
i = 1j

# %%
i**2
# Out:
# (-1+0j)

# %%
phi = 523098
np.e**(i*phi) == np.cos(phi) + i*np.sin(phi)
# Out:
# True

# %%
def plot_e(phi, color='black', magnitude=1):
    c = magnitude * np.e**(i*phi)
    x, y = c.real, c.imag
    
    

    ax.arrow(0, 0, x, y, width=0.01, color=color)

# %%
ax = plt.axes()
plt.grid()

plt.xlim(-2,2)
plt.ylim(-2,2)

plot_e(0.25*np.pi,  'green', 2)
plot_e(0.5*np.pi, 'red')
plot_e(0.75*np.pi, 'blue')
plot_e(np.pi, 'YELLOW')
plot_e(1.5*np.pi, 'brown')
plot_e(2*np.pi, 'grey')
plot_e(1.75*np.pi, 'olive')

# %%
xx = [np.e**(i*phi) for phi in np.lins(-np.pi, np.pi)]

# %%
import matplotlib.pyplot as plt
plt.plot(xx)
